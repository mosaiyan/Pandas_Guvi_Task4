# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("/content/college_1.csv")
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2=pd.read_csv("/content/college_2.csv")
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
#merging two csv files
df3=[df1,df2]
df=pd.concat(df3)
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
Exceeded_expectations=df[df["CodeKata Score"]>15000]
Exceeded_expectations.to_csv("Exceeded_expectations.csv")
Exceeded_expectations
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 0                     9.0

# %%
#or
'''Exceeded_expectations=df[df["CodeKata Score"]>15000]
codekata=pd.DataFrame(Exceeded_expectations)
codekata.to_csv("Exceeded_expectations.csv")'''
# Out:
# 'Exceeded_expectations=df[df["CodeKata Score"]>15000]\ncodekata=pd.DataFrame(Exceeded_expectations)\ncodekata.to_csv("Exceeded_expectations.csv")'

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations=df[df["CodeKata Score"].between(10000,15000)]
Reached_expectations.to_csv("Reached_expectations.csv")
Reached_expectations
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_expectations=df[df["CodeKata Score"].between(7000,10000)]
Needs_expectations.to_csv("Needs_expectations.csv")
Needs_expectations
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory=df[df["CodeKata Score"]<7000]
Unsatisfactory.to_csv("Unsatisfactory.csv")
Unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg1=df["Previous Geekions"].mean()
avg1
# Out:
# 3842.3529411764707

# %%
avg2=df["CodeKata Score"].mean()
avg2
# Out:
# 4051.764705882353

# %%
mean=df[["Previous Geekions","CodeKata Score"]].mean()
mean
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %%
plt.bar('Previous Geekions',avg1,width=0.6)
plt.bar('CodeKata Score',avg2,width=0.6)
plt.show()

# %% [markdown]
# ###### No of students participated

# %%
no_students=len(df['Name'])
no_students
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
avgpy_course=df["python"].mean()
avgpy_course
# Out:
# 54.35294117647059

# %%
avg_compl=df["python"]/len(df["python"])
print("The average completion of python:",avg_compl)
print("The average completion of python:",avgpy_course)
# Out:
# The average completion of python: 0     0.689076
# 1     0.689076
# 2     0.840336
# 3     0.840336
# 4     0.840336
#         ...
# 30    0.201681
# 31   -0.008403
# 32    0.268908
# 33   -0.008403
# 34   -0.008403
# Name: python, Length: 119, dtype: float64
# The average completion of python: 54.35294117647059

# %%
#or
'''avgmysql_course=df["mysql"].mean()
avgmysql_course'''
# Out:
# 23.5

# %%
'''avg_compl1=df["mysql"]/len(df["mysql"])
print("The average completion of mysql:",avg_compl1)
print("The average completion of mysql:",avgmysql_course)'''
# Out:
# The average completion of mysql: 0     0.168067
# 1     0.168067
# 2     0.840336
# 3     0.394958
# 4     0.067227
#         ...
# 30    0.000000
# 31    0.100840
# 32    0.000000
# 33   -0.008403
# 34   -0.008403
# Name: mysql, Length: 119, dtype: float64
# The average completion of mysql: 23.5

# %%
#or
'''avgpy_en_course=df["python_en"].mean()
avgpy_en_course'''
# Out:
# 29.65714285714286

# %%
'''avg_compl2=df["python_en"]/len(df["python_en"])
print("The average completion of python_en:",avg_compl2)
print("The average completion of python_en:",avgpy_en_course)'''
# Out:
# 'avg_compl2=df["python_en"]/len(df["python_en"])\nprint("The average completion of python_en:",avg_compl2)\nprint("The average completion of python_en:",avgpy_en_course)'

# %%
#or
'''avgcomp_th_course=df["computational_thinking"].mean()
avgcomp_th_course'''
# Out:
# 2.2

# %%
'''avg_compl3=df["computational_thinking"]/len(df["computational_thinking"])
print("The average completion of python_en:",avg_compl3)
print("The average completion of python_en:",avgcomp_th_course)'''
# Out:
# The average completion of python_en: 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 30    0.000000
# 31   -0.008403
# 32   -0.008403
# 33   -0.008403
# 34    0.000000
# Name: computational_thinking, Length: 119, dtype: float64
# The average completion of python_en: 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_stars=df.nlargest(3,'Rising')
rising_stars
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 2         Computer Science and Engineering    2000       55.0
# 18        Computer Science and Engineering    2000       -1.0
#
#     computational_thinking
# 8                      0.0
# 2                      6.0
# 18                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_stars=df.nlargest(3,'Previous Geekions')
shining_stars
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
fig=px.pie(df,names="Department",values="CodeKata Score",title="Department wise codekata performence")
fig.update_traces(textinfo='label+percent',textposition="outside",pull=0.2)#use hole for donut chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df["Total_Marks"]=df["python"]+df["mysql"]+df["Previous Geekions"]+df["CodeKata Score"]+df["Rising"]+df["python_en"]+df["computational_thinking"]
df["Total_Marks"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 30    4783.0
# 31    3842.0
# 32    3520.0
# 33      17.0
# 34      -3.0
# Name: Total_Marks, Length: 119, dtype: float64

# %%
df.groupby("Department").max()
# Out:
#                                                      Name  python  mysql  \
# Department
# Computer Science and Engineering              vijayakumar   100.0  100.0
# Electronics and Communication Engineering       vignesh B   100.0  100.0
# Electronics and Electrical Engineering     yaser ahamed.A   100.0  100.0
#
#                                            Previous Geekions  CodeKata Score  \
# Department
# Computer Science and Engineering                       24500           24500
# Electronics and Communication Engineering              10040           10040
# Electronics and Electrical Engineering                 19400           19400
#
#                                            Rising  python_en  \
# Department
# Computer Science and Engineering             2000       78.0
# Electronics and Communication Engineering     560       72.0
# Electronics and Electrical Engineering       3140      100.0
#
# ...

# %%
color=["Orange","Red","Green"]
df.groupby(["Department"]).max().plot(kind='pie', y='Total_Marks', autopct='%2.0f%%', labels=["vijayakumar","vignesh B","yaser ahamed.A"],title="Department wise toppers",
                                      colors=color,figsize=(7,9))
